# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/bmalcover/AppOC/blob/main/docs/notebooks/04_Images/04_Projecte.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Project
#
# <img src="../../_static/04/fish.jpg" width="500" />
#
# No we will use the [Marine Image Dataset for Classification](https://www.kaggle.com/datasets/ananya12verma/marine-image-dataset-for-classification/data). Is a public available dataset in Kaggle an open platform of datasets:
#
# 1. Download the dataset.
#
# 2. Fine-tunne a VGG16 and a DenseNet121 model to predict the classes.
#
# 3. Obtain the accuracy of the models and compare them.
#
# 4. Repeat the point two but now do data augmentation, compare the results of these models and the previous ones.
